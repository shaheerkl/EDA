# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\PycharmProjects\JupyterProject1\Iris_missingdata.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           NaN            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Species']=le.fit_transform(df['Species'])

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            NaN           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           NaN            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
minmax=MinMaxScaler()

# %%
x=df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              NaN           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           NaN            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df['Species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
x1=minmax.fit_transform(x)
x1
# Out:
# array([[0.2       , 0.625     , 0.06779661, 0.04166667],
#        [0.14285714, 0.41666667, 0.06779661, 0.04166667],
#        [0.08571429, 0.5       , 0.05084746, 0.04166667],
#        [       nan, 0.45833333, 0.08474576, 0.04166667],
#        [0.17142857, 0.66666667, 0.06779661, 0.04166667],
#        [0.28571429, 0.79166667, 0.11864407, 0.125     ],
#        [0.05714286, 0.58333333, 0.06779661, 0.08333333],
#        [0.17142857, 0.58333333, 0.08474576, 0.04166667],
#        [0.        , 0.375     , 0.06779661, 0.04166667],
#        [0.14285714, 0.45833333,        nan, 0.        ],
#        [0.28571429, 0.70833333, 0.08474576, 0.04166667],
#        [0.11428571, 0.58333333, 0.10169492, 0.04166667],
#        [0.11428571, 0.41666667, 0.06779661, 0.        ],
#        [       nan, 0.41666667, 0.01694915, 0.        ],
#        [0.4       ,        nan, 0.03389831, 0.04166667],
#        [0.37142857, 1.        , 0.08474576, 0.125     ],
# ...

# %%
x2=pd.DataFrame(x1, columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
x2
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0         0.200000      0.625000       0.067797      0.041667
# 1         0.142857      0.416667       0.067797      0.041667
# 2         0.085714      0.500000       0.050847      0.041667
# 3              NaN      0.458333       0.084746      0.041667
# 4         0.171429      0.666667       0.067797      0.041667
# ..             ...           ...            ...           ...
# 145       0.657143      0.416667       0.711864      0.916667
# 146       0.542857           NaN       0.677966      0.750000
# 147       0.600000      0.416667       0.711864      0.791667
# 148       0.514286      0.583333       0.745763      0.916667
# 149       0.428571      0.416667       0.694915      0.708333
#
# [150 rows x 4 columns]

# %%
x3=pd.concat([x2,y], axis=1)
x3
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0         0.200000      0.625000       0.067797      0.041667        0
# 1         0.142857      0.416667       0.067797      0.041667        0
# 2         0.085714      0.500000       0.050847      0.041667        0
# 3              NaN      0.458333       0.084746      0.041667        0
# 4         0.171429      0.666667       0.067797      0.041667        0
# ..             ...           ...            ...           ...      ...
# 145       0.657143      0.416667       0.711864      0.916667        2
# 146       0.542857           NaN       0.677966      0.750000        2
# 147       0.600000      0.416667       0.711864      0.791667        2
# 148       0.514286      0.583333       0.745763      0.916667        2
# 149       0.428571      0.416667       0.694915      0.708333        2
#
# [150 rows x 5 columns]

# %%
x3.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species
# count     139.000000    143.000000     142.000000    141.000000  150.000000
# mean        0.411922      0.437646       0.471234      0.457742    1.000000
# std         0.234420      0.180329       0.301310      0.318026    0.819232
# min         0.000000      0.000000       0.000000      0.000000    0.000000
# 25%         0.200000      0.333333       0.101695      0.083333    0.000000
# 50%         0.400000      0.416667       0.576271      0.500000    1.000000
# 75%         0.571429      0.541667       0.694915      0.708333    2.000000
# max         1.000000      1.000000       1.000000      1.000000    2.000000
