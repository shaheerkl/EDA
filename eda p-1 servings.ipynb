# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.lib.pretty import Printable

# %%
# EDA(exploratory data analysis)

# %%
df = pd.read_csv(r"C:\Users\HP\PycharmProjects\JupyterProject1\archive\beer-servings.csv")
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0           0  Afghanistan            0.0              0.0            0.0
# 1           1      Albania           89.0            132.0           54.0
# 2           2      Algeria           25.0              0.0           14.0
# 3           3      Andorra          245.0            138.0          312.0
# 4           4       Angola          217.0             57.0           45.0
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.tail()
# Out:
#      Unnamed: 0    country  beer_servings  spirit_servings  wine_servings  \
# 188         188  Venezuela            NaN            100.0            3.0
# 189         189    Vietnam          111.0              2.0            1.0
# 190         190      Yemen            6.0              0.0            0.0
# 191         191     Zambia           32.0             19.0            4.0
# 192         192   Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 188                           7.7  South America
# 189                           2.0           Asia
# 190                           0.1           Asia
# 191                           2.5         Africa
# 192                           4.7         Africa

# %%
df.shape
# Out:
# (193, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    193 non-null    int64
#  1   country                       193 non-null    object
#  2   beer_servings                 185 non-null    float64
#  3   spirit_servings               185 non-null    float64
#  4   wine_servings                 187 non-null    float64
#  5   total_litres_of_pure_alcohol  192 non-null    float64
#  6   continent                     193 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 10.7+ KB

# %%
df.describe()
# Out:
#        Unnamed: 0  beer_servings  spirit_servings  wine_servings  \
# count  193.000000     185.000000       185.000000     187.000000
# mean    96.000000     105.124324        83.221622      50.165775
# std     55.858452     100.524714        89.142958      80.358868
# min      0.000000       0.000000         0.000000       0.000000
# 25%     48.000000      20.000000         4.000000       1.000000
# 50%     96.000000      76.000000        60.000000       9.000000
# 75%    144.000000     185.000000       132.000000      60.500000
# max    192.000000     376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    192.000000
# mean                       4.741667
# std                        3.767654
# min                        0.000000
# 25%                        1.300000
# 50%                        4.250000
# 75%                        7.200000
# max                       14.400000

# %%
df.dtypes
# Out:
# Unnamed: 0                        int64
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'beer_servings', 'spirit_servings',
#        'wine_servings', 'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela            NaN            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
freqgraph = df.select_dtypes('float')
freqgraph
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            245.0            138.0          312.0
# 4            217.0             57.0           45.0
# ..             ...              ...            ...
# 188            NaN            100.0            3.0
# 189          111.0              2.0            1.0
# 190            6.0              0.0            0.0
# 191           32.0             19.0            4.0
# 192           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol
# 0                             0.0
# 1                             4.9
# 2                             0.7
# 3                            12.4
# 4                             5.9
# ..                            ...
# 188                           7.7
# 189                           2.0
# ...

# %%
freqgraph.hist(color='yellow')
# Out:
# array([[<Axes: title={'center': 'beer_servings'}>,
#         <Axes: title={'center': 'spirit_servings'}>],
#        [<Axes: title={'center': 'wine_servings'}>,
#         <Axes: title={'center': 'total_litres_of_pure_alcohol'}>]],
#       dtype=object)

# %%
df1=df.fillna(df['beer_servings'].median())
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela           76.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
df1
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan            0.0              0.0            0.0
# 1        Albania           89.0            132.0           54.0
# 2        Algeria           25.0              0.0           14.0
# 3        Andorra          245.0            138.0          312.0
# 4         Angola          217.0             57.0           45.0
# ..           ...            ...              ...            ...
# 188    Venezuela           76.0            100.0            3.0
# 189      Vietnam          111.0              2.0            1.0
# 190        Yemen            6.0              0.0            0.0
# 191       Zambia           32.0             19.0            4.0
# 192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
for i in ['beer_servings', 'spirit_servings','wine_servings',
     'total_litres_of_pure_alcohol']:
    df[i]=df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
num_cols=['beer_servings', 'spirit_servings',
       'wine_servings', 'total_litres_of_pure_alcohol']
sns.boxplot(df[num_cols])
plt.show()

# %%
Q1= np.percentile(df['spirit_servings'], 25, method="midpoint")
Q2= np.percentile(df['spirit_servings'], 50, method='midpoint')
Q3= np.percentile(df['spirit_servings'], 75, method='midpoint')

print(Q1,Q2,Q3)
# Out:
# 5.0 60.0 128.0

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(123.0)

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR

print(upper_limit, lower_limit)
# Out:
# 312.5 -179.5

# %%
outliers=[]
for x in df['spirit_servings']:
    if((x > upper_limit) or (x < lower_limit)):
        outliers.append(x)
outliers
# Out:
# [373.0, 438.0, 326.0, 326.0, 315.0]

# %%
df2=df['spirit_servings'] > upper_limit
df2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: spirit_servings, Length: 193, dtype: bool

# %%
df.loc[df2]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus          142.0            373.0           42.0
# 68              Grenada          199.0            438.0           28.0
# 73                Haiti            1.0            326.0            1.0
# 141  Russian Federation          247.0            326.0           73.0
# 144           St. Lucia          171.0            315.0           71.0
#
#      total_litres_of_pure_alcohol      continent
# 15                           14.4         Europe
# 68                           11.9  North America
# 73                            5.9  North America
# 141                          11.5           Asia
# 144                          10.1  North America

# %%
remove=[15,68,73,141,144]
df.drop(remove, inplace=True)

# %%
outliers=[]

# %%
for x in df['spirit_servings']:
    if((x > upper_limit) or (x < lower_limit)):
        outliers.append()
outliers
# Out:
# []

# %%
Q1=np.percentile(df['wine_servings'], 25, method="midpoint")
Q2=np.percentile(df['wine_servings'], 50, method='midpoint')
Q3=np.percentile(df['wine_servings'], 75, method='midpoint')

print(Q1,Q2,Q3)
# Out:
# 1.0 9.0 57.5

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(56.5)

# %%
upper_limit=Q3+1.5*IQR
lower_limit=Q1-1.5*IQR
print(upper_limit, lower_limit)
# Out:
# 142.25 -83.75

# %%
outliers=[]
for x in df['wine_servings']:
    if((x > upper_limit) or (x < lower_limit)):
        outliers.append(x)
outliers
# Out:
# [312.0,
#  221.0,
#  212.0,
#  191.0,
#  212.0,
#  172.0,
#  254.0,
#  278.0,
#  233.0,
#  370.0,
#  149.0,
#  175.0,
#  218.0,
#  185.0,
#  165.0,
#  237.0,
#  271.0,
#  190.0,
#  175.0,
#  339.0,
#  167.0,
#  276.0,
#  186.0,
#  280.0,
#  195.0,
#  220.0]

# %%
df4=df['wine_servings'] > upper_limit
df4
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Name: wine_servings, Length: 188, dtype: bool

# %%
df.loc[df4]
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 3              Andorra          245.0            138.0          312.0
# 6            Argentina           76.0             25.0          221.0
# 8            Australia          261.0             72.0          212.0
# 9              Austria          279.0             75.0          191.0
# 16             Belgium          295.0             84.0          212.0
# 35               Chile          130.0            124.0          172.0
# 42             Croatia          230.0             87.0          254.0
# 48             Denmark          224.0             81.0          278.0
# 55   Equatorial Guinea           92.0              0.0          233.0
# 61              France          127.0            151.0          370.0
# 64             Georgia           76.0            100.0          149.0
# 65             Germany          346.0            117.0          175.0
# ...

# %%
r=[3,6,8,9,16,35,42,48,55,61,65,67,75,81,83,99,120,121,136,140,156,165,166,182,185]
df.drop(r, inplace=True)

# %%
outliers=[]
for x in df['wine_servings']:
    if ((x > upper_limit) or (x < lower_limit)):
        outliers.append(x)
outliers
# Out:
# [149.0]

# %%
df.drop(64, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 0          Afghanistan            0.0              0.0            0.0
# 1              Albania           89.0            132.0           54.0
# 2              Algeria           25.0              0.0           14.0
# 3               Angola          217.0             57.0           45.0
# 4    Antigua & Barbuda          102.0            128.0           45.0
# ..                 ...            ...              ...            ...
# 157          Venezuela           76.0            100.0            3.0
# 158            Vietnam          111.0              2.0            1.0
# 159              Yemen            6.0              0.0            0.0
# 160             Zambia           32.0             19.0            4.0
# 161           Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# ...

# %%
# ONE HOT ENCODING

# %%
df.country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antigua & Barbuda',
#        'Armenia', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh',
#        'Barbados', 'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bosnia-Herzegovina', 'Botswana', 'Brazil', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Burundi', "Cote d'Ivoire", 'Cabo Verde',
#        'Cambodia', 'Cameroon', 'Canada', 'Central African Republic',
#        'Chad', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', 'Cuba', 'Cyprus', 'Czech Republic', 'North Korea',
#        'DR Congo', 'Djibouti', 'Dominica', 'Dominican Republic',
#        'Ecuador', 'Egypt', 'El Salvador', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Fiji', 'Finland', 'Gabon', 'Gambia', 'Ghana',
#        'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Honduras',
#        'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
# ...

# %%
df.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania'], dtype=object)

# %%
# df.drop('country', axis=1, inplace=True)

# %%
# df1=pd.get_dummies(df)
# df1

# %%
# df_1=pd.get_dummies(df1)
# df_1
# df_1.astype(int)

# %%
# LABEL ENCODING

# %%
df.head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan            0.0              0.0            0.0
# 1            Albania           89.0            132.0           54.0
# 2            Algeria           25.0              0.0           14.0
# 3             Angola          217.0             57.0           45.0
# 4  Antigua & Barbuda          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                           5.9         Africa
# 4                           4.9  North America

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df.drop('country', axis=1, inplace=True)

# %%
df['continent']=le.fit_transform(df['continent'])

# %%
df.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  \
# 0            0.0              0.0            0.0
# 1           89.0            132.0           54.0
# 2           25.0              0.0           14.0
# 3          217.0             57.0           45.0
# 4          102.0            128.0           45.0
#
#    total_litres_of_pure_alcohol  continent
# 0                           0.0          1
# 1                           4.9          2
# 2                           0.7          0
# 3                           5.9          0
# 4                           4.9          3

# %%
df
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            217.0             57.0           45.0
# 4            102.0            128.0           45.0
# ..             ...              ...            ...
# 157           76.0            100.0            3.0
# 158          111.0              2.0            1.0
# 159            6.0              0.0            0.0
# 160           32.0             19.0            4.0
# 161           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol  continent
# 0                             0.0          1
# 1                             4.9          2
# 2                             0.7          0
# 3                             5.9          0
# 4                             4.9          3
# ..                            ...        ...
# ...

# %%
# SCALING

# %%
# MINMAX SCALING

x=df.drop(['total_litres_of_pure_alcohol', 'continent'],axis=1)

# %%
y=df[['total_litres_of_pure_alcohol', 'continent']]

# %%
x
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0              0.0              0.0            0.0
# 1             89.0            132.0           54.0
# 2             25.0              0.0           14.0
# 3            217.0             57.0           45.0
# 4            102.0            128.0           45.0
# ..             ...              ...            ...
# 157           76.0            100.0            3.0
# 158          111.0              2.0            1.0
# 159            6.0              0.0            0.0
# 160           32.0             19.0            4.0
# 161           64.0             18.0            4.0
#
# [162 rows x 3 columns]

# %%
y
# Out:
#      total_litres_of_pure_alcohol  continent
# 0                             0.0          1
# 1                             4.9          2
# 2                             0.7          0
# 3                             5.9          0
# 4                             4.9          3
# ..                            ...        ...
# 157                           7.7          5
# 158                           2.0          1
# 159                           0.1          1
# 160                           2.5          0
# 161                           4.7          0
#
# [162 rows x 2 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
x1=minmax.fit_transform(x)
x1
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.23670213, 0.43708609, 0.40298507],
#        [0.06648936, 0.        , 0.10447761],
#        [0.57712766, 0.18874172, 0.3358209 ],
#        [0.2712766 , 0.42384106, 0.3358209 ],
#        [0.05585106, 0.59271523, 0.08208955],
#        [0.05585106, 0.15231788, 0.03731343],
#        [0.32446809, 0.58278146, 0.38059701],
#        [0.11170213, 0.20860927, 0.05223881],
#        [0.20212766, 0.1986755 , 0.06716418],
#        [0.38031915, 0.57284768, 0.26865672],
#        [0.69946809, 0.37748344, 0.05970149],
#        [0.09042553, 0.01324503, 0.09701493],
#        [0.06117021, 0.        , 0.        ],
#        [0.44414894, 0.13576159, 0.05970149],
#        [0.20212766, 0.57284768, 0.05970149],
#        [0.46010638, 0.11589404, 0.26119403],
#        [0.65159574, 0.48013245, 0.11940299],
#        [0.08244681, 0.00662252, 0.00746269],
#        [0.6143617 , 0.83443709, 0.70149254],
#        [0.06648936, 0.1986755 , 0.05223881],
# ...

# %%
x2=pd.DataFrame(x1, columns=['beer_servings', 'spirit_servings', 'wine_servings'])
x2
# Out:
#      beer_servings  spirit_servings  wine_servings
# 0         0.000000         0.000000       0.000000
# 1         0.236702         0.437086       0.402985
# 2         0.066489         0.000000       0.104478
# 3         0.577128         0.188742       0.335821
# 4         0.271277         0.423841       0.335821
# ..             ...              ...            ...
# 157       0.202128         0.331126       0.022388
# 158       0.295213         0.006623       0.007463
# 159       0.015957         0.000000       0.000000
# 160       0.085106         0.062914       0.029851
# 161       0.170213         0.059603       0.029851
#
# [162 rows x 3 columns]

# %%
x3=pd.concat([x2,y], axis=1)
x3
# Out:
#      beer_servings  spirit_servings  wine_servings  \
# 0         0.000000         0.000000       0.000000
# 1         0.236702         0.437086       0.402985
# 2         0.066489         0.000000       0.104478
# 3         0.577128         0.188742       0.335821
# 4         0.271277         0.423841       0.335821
# ..             ...              ...            ...
# 157       0.202128         0.331126       0.022388
# 158       0.295213         0.006623       0.007463
# 159       0.015957         0.000000       0.000000
# 160       0.085106         0.062914       0.029851
# 161       0.170213         0.059603       0.029851
#
#      total_litres_of_pure_alcohol  continent
# 0                             0.0          1
# 1                             4.9          2
# 2                             0.7          0
# 3                             5.9          0
# 4                             4.9          3
# ..                            ...        ...
# ...

# %%
x3.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     162.000000       162.000000     162.000000
# mean        0.230299         0.239208       0.153722
# std         0.244585         0.262603       0.248742
# min         0.000000         0.000000       0.000000
# 25%         0.045878         0.009934       0.007463
# 50%         0.144947         0.142384       0.052239
# 75%         0.337766         0.399834       0.139925
# max         1.000000         1.000000       1.000000
#
#        total_litres_of_pure_alcohol   continent
# count                    162.000000  162.000000
# mean                       3.784259    1.555556
# std                        3.201923    1.528203
# min                        0.000000    0.000000
# 25%                        1.000000    0.000000
# 50%                        2.800000    1.000000
# 75%                        6.300000    3.000000
# max                       12.900000    5.000000
