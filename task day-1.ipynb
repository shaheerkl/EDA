# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import heatmap

# %%
# 1-Load a dataset with missing values

df=pd.read_csv(r"C:\Users\HP\PycharmProjects\JupyterProject1\archive\beer-servings.csv")
df
# Out:
#      Unnamed: 0      country  beer_servings  spirit_servings  wine_servings  \
# 0             0  Afghanistan            0.0              0.0            0.0
# 1             1      Albania           89.0            132.0           54.0
# 2             2      Algeria           25.0              0.0           14.0
# 3             3      Andorra          245.0            138.0          312.0
# 4             4       Angola          217.0             57.0           45.0
# ..          ...          ...            ...              ...            ...
# 188         188    Venezuela            NaN            100.0            3.0
# 189         189      Vietnam          111.0              2.0            1.0
# 190         190        Yemen            6.0              0.0            0.0
# 191         191       Zambia           32.0             19.0            4.0
# 192         192     Zimbabwe           64.0             18.0            4.0
#
#      total_litres_of_pure_alcohol      continent
# ...

# %%
# 2-Find how many nulls are in each column

df.isnull().sum()
# Out:
# Unnamed: 0                      0
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
# 3-What function is used to check for missing values in Pandas?

# df.isnull()
# Out:
#      Unnamed: 0  country  beer_servings  spirit_servings  wine_servings  \
# 0         False    False          False            False          False
# 1         False    False          False            False          False
# 2         False    False          False            False          False
# 3         False    False          False            False          False
# 4         False    False          False            False          False
# ..          ...      ...            ...              ...            ...
# 188       False    False           True            False          False
# 189       False    False          False            False          False
# 190       False    False          False            False          False
# 191       False    False          False            False          False
# 192       False    False          False            False          False
#
#      total_litres_of_pure_alcohol  continent
# 0                           False      False
# ...

# %%
# 4-Count null values in a specific column.

df["beer_servings"].isnull().sum()
# Out:
# np.int64(8)

# %%
# 5-Create a summary of total missing values in a dataset.

df.isnull().sum()
# Out:
# Unnamed: 0                      0
# country                         0
# beer_servings                   8
# spirit_servings                 8
# wine_servings                   6
# total_litres_of_pure_alcohol    1
# continent                       0
# dtype: int64

# %%
# 6-Visualize missing data with a Seaborn heatmap.

df.dtypes
# Out:
# Unnamed: 0                        int64
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                   float64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
heat= df.select_dtypes('float')

# %%
corr=heat.corr()
sns.heatmap(df.isnull(),cbar=False)
plt.show()

# %%
# 7-Why is it important to identify missing values before analysis?

# 1. Missing values can give wrong results
# 2. Many machine learning models don’t accept missing values
# 3. Missing values can hide patterns
# 4. Helps you decide how to fix the data
# 4. Helps you decide how to fix the data
